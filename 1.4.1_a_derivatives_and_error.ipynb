# %%
print('Anna Marie Rooney')

print('19333456')

print('Assignment One, part one, Hutzler')
# Out:
# Anna Marie Rooney
# 19333456
# Assignment One, part one, Hutzler

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#defining the functions
import numpy as np

import matplotlib.pyplot as plt

#cos 
def y(x) :
   f= np.cos(x)
   return f

#derivative of cos x
def dy(x):
    j= -np.sin(x)
    return j

#second derivative of cos x
def dy2(x):
    j= -np.sin(x)
    return j

#e func
def g(x):
    f= np.exp(x) 
    return f

#e derivative
def dg(x):
    j= np.exp(x)
    return j

#forward difference
def fd(func, t, h):
    c = (func(t+h) - func(t))/h
    return c

#central difference    
def cd(func, t, h):
    c = (func(t+(h/2)) - func(t-(h/2)))/h
    return c

# central difference for the second derivative
def cd2(func, t, h):
    if h < np.finfo(float).eps:
        print("h is smaller than epsilon, cd2 function returning float.")  
        return np.nan  
    f = (func(t+h)+func(t-h)-2*func(t))/(h**2)
    return f

#the absolute difference between the method and the function
def dif(method, func, t,h):
    l = abs(method(func, t,h) - func(t))
    return l

#log of difference of difference minus the derivative
def logdif(func, t, h):
    difference = dif(func, t, h)  #calculate the absolute difference. 
    if difference > 0:
        return np.log10(difference)  #take log 10 if positive
    else:
        return np.nan  #return nan if the difference is negative or 0 to avoid log errors

plot_files = []

# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import numpy as np
"""part one"""

hlist = np.linspace((np.pi)/10, 2.220446049250313e-16, 5)
listnum=[0,1,2,3]
t= np.arange(0, 25, 0.05)

name = ['cos(x)', '$e^x$']
fu = [fd, cd, cd2]
funame = ['Forward Differrence', 'Central Difference', 'Central Difference for second derivative']

name2 = ['cos(x)', 'e_x']
funame2 = ['Forward_Differrence', 'Central_Difference', 'Central_Difference_for_second_derivative_']
#ccreating a dictionary: 
points_of_interest = [5, 10, 15, 20]  #values of 't'

#dictionary to store results for each method and function
results = {
    'method': [],
    'function': [],
    'point': [],
    'stepsize': [],
    'num_d': [],
    'anal_d': [],
    'rel_error': []
}

N = 1000
tlist= (0.1, 1, 100)

# Select t = 0.1 for plotting
selected_t = 0.1

pathdir = '1.4.1a_plots/'
if not os.path.exists(pathdir):
    os.makedirs(pathdir)

float_epsilon = np.finfo(float).eps
colors=["red", "blue", "green", "orange", "yellow"]

for k in range(3): #controlling the method used
    f = fu[k]
    for z in range(2):#controlling the function used (e^x or cos(x))
        if z ==0:
            func = y
            funcd = dy
        if z ==1:
            func = g
            funcd = dg
                
        #to collect the derivatives at t points of interest we use a loop 
        for t_point in points_of_interest:
            for h in hlist:  # for each step size
                #nmerical and analytical derivative using the calculated function
                num_d= f(func, t_point, h)
                anal_d = funcd(t_point)
                
                #relative error
                rel_error = abs(num_d - anal_d) / abs(anal_d)

                # Store the results
                results['method'].append(funame[k])
                results['function'].append(name[z])
                results['point'].append(t_point)
                results['stepsize'].append(h)
                results['num_d'].append(num_d)
                results['anal_d'].append(anal_d)
                results['rel_error'].append(rel_error)
                
        for m in range(2): #making the plots
            if z== 0 and m ==1: 
                plt.xlim(4,5)
                plt.ylim(0.97, 1)
            if z==1 and m == 1:  #limits
                plt.xlim(24.1, 24.4)
                plt.ylim(3e10, 3.8e10)
            if k==2 and z==0 and m==1:  #limits
                plt.xlim(2.6,5)
                plt.ylim(0.97, 1)
            
            plt.plot(t, f(func, t, hlist[0]), label = 'h = %s'%hlist[0],  linestyle = '--', linewidth = 0.8, color = 'green')
            plt.plot(t, f(func, t, hlist[1]), label = 'h = %s'%hlist[1],  linestyle = '--', linewidth = 0.8, color = 'pink')
            plt.plot(t, f(func, t, hlist[2]), label = 'h = %s'%hlist[2],  linestyle = '--', linewidth = 0.8, color = 'red')
            plt.plot(t, f(func, t, hlist[3]), label = 'h = %s'%hlist[3],  linestyle = '--', linewidth = 0.8, color = 'blue')

            plt.plot(t, funcd(t), color='blue', label = "analytical derivative")
                
            plt.title(fr"{funame[k]} of {name[z]} vs analytical") 
            plt.ylabel(fr"derivative of {name[z]}")                      
            plt.xlabel("t")  
            plt.legend()

            #SAVE the plot to the directory
            pathdir = '1.4.1a_plots/derivatives'
            if not os.path.exists(pathdir):
                os.makedirs(pathdir)
            save_path = os.path.join(pathdir, fr"{funame2[k]}_derivatives_{name2[z]}_{m}.png")
            plt.savefig(save_path)  #save the figure as a .png file
            #print(f"Plot saved to: {save_path}")
            plot_files.append(save_path)

            #show the plot
            plt.show()

            #clear figure so plots dont overlap.
            plt.clf()
        
            for r in range(len(tlist)):
                tt = tlist[r]
                hh = 2*np.pi
                dlist = []
                rlist = []
                hslist = []
                print('round ', r)
                for n in range(N):
                    hh = hh/2
                    j = dif(f, func, tt ,hh)
                    dlist.append(j)
                    hslist.append(hh)
                    if hh < float_epsilon or np.isnan(h):
                        break
                #print('h has reached', h, 'plots now being made. ')
                plt.loglog(hslist, dlist, label=fr"t={tt}", color=colors[r])
                plt.title(fr"Reducing step size h to $\epsilon_m$ vs absolute error for {name[z]} using the {funame[k]}")
                print(fr"Reducing step size h to $\epsilon_m$ vs absolute error for {name[z]} using the {funame[k]}")
                plt.ylabel(fr"absolute error as a function of h")                      
                plt.xlabel("Step size h")  
            plt.axvline(x=float_epsilon, color='pink', linestyle='--', label=r'$\epsilon_{m}$')
            plt.legend()
                
            #SAVE the plot to the directory
            pathdir = '1.4.1a_plots/absolute_errors'
            if not os.path.exists(pathdir):
                os.makedirs(pathdir)
            save_path = os.path.join(pathdir, f"difference_with_{tt}_for_{name2[z]}_{funame2[k]}.png")
            plt.savefig(save_path)  #save the figure as a .png file
            #print(f"Plot saved to: {save_path}")
            plot_files.append(save_path)

            #show the plot
            plt.show()

            #clear figure so plots dont overlap.
            plt.clf()
# Out:
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Forward Differrence
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Forward Differrence
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Forward Differrence
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Forward Differrence
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Forward Differrence
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Forward Differrence
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Forward Differrence
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Forward Differrence
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Forward Differrence
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Forward Differrence
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Forward Differrence
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Forward Differrence
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference
# round  0
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference
# round  1
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference
# round  2
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference
# round  0
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference for second derivative
# round  1
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference for second derivative
# round  2
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference for second derivative
# round  0
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference for second derivative
# round  1
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference for second derivative
# round  2
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for cos(x) using the Central Difference for second derivative
# round  0
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference for second derivative
# round  1
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference for second derivative
# round  2
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference for second derivative
# round  0
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference for second derivative
# round  1
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference for second derivative
# round  2
# h is smaller than epsilon, cd2 function returning float.
# Reducing step size h to $\epsilon_m$ vs absolute error for $e^x$ using the Central Difference for second derivative

# %%
# Loop over functions (cos(x) and e^x)
for z in range(2):
    if z == 0:
        func = y
        funcd = dy
    elif z == 1:
        func = g
        funcd = dg

    plt.figure(figsize=(8, 6))
    
    for k in range(3):  
        f = fu[k]
        if k == 2 and z == 0:
            continue
        hh = 2 * np.pi
        dlist = []
        hslist = []

        for n in range(1000):
            hh = hh / 2
            error = dif(f, func, selected_t, hh)
            dlist.append(error)
            hslist.append(hh)
            if hh < float_epsilon or np.isnan(hh):
                break

        plt.loglog(hslist, dlist, label=fr"{funame[k]} for {name[z]}", color=colors[k])


    plt.title(fr"Absolute Error vs Step Size h for {name[z]} using Different Methods (t = {selected_t})")
    plt.xlabel("Step size h")
    plt.ylabel("Absolute Error")
    plt.axvline(x=float_epsilon, color='pink', linestyle='--', label=r'$\epsilon_{m}$')  # Machine epsilon line
    plt.legend()

    save_path = os.path.join(pathdir, f"absolute_error_combined_{name[z]}.png")
    plt.savefig(save_path)  # Save the figure as a .png file
    print(f"Plot saved to: {save_path}")

    plt.show()

    plt.clf()
# Out:
# Plot saved to: 1.4.1a_plots/absolute_errors/absolute_error_combined_cos(x).png
# h is smaller than epsilon, cd2 function returning float.
# Plot saved to: 1.4.1a_plots/absolute_errors/absolute_error_combined_$e^x$.png

# %%
fig, (ax2, ax1) = plt.subplots(1, 2)
ax2.plot(cd2(y, t, hlist[4]), label = 'h = %s'%hlist[4], linestyle = '--', linewidth = 0.8, color = 'orange')
ax2.plot(dy(t), label = 'analytical 2nd derivative', linestyle = '--', linewidth = 1, color= 'black')

fig.suptitle('second central difference derivative of cos(x) at machine precision')
ax2.set_xlabel('t')
ax2.set_ylabel('cos(t)')
ax2.set_xlim(0,90)
ax2.set_ylim(-1,1)

#futher away
ax2.plot(cd2(y, t,hlist[4]), label="_nolegend_" , linestyle = '--', linewidth = 0.8, color = 'orange')
ax2.plot(dy(t), label="_nolegend_" , linestyle = '--', linewidth = 1, color= 'black')

#close up
ax1.plot(cd2(y, t,hlist[4]), label = 'h = %s'%hlist[4], linestyle = '--', linewidth = 0.8,color = 'orange')
ax1.plot(dy(t), label = 'analytical 2nd derivative', linestyle = '--', linewidth = 1, color= 'black')
ax1.set_xlim(0,100)

ax2.legend(bbox_to_anchor = (0.6, -0.1), ncol=1) 
ax1.grid(color = 'green', linestyle = '--', linewidth = 0.4)
plt.show()

# %%
#using pandaas-- first convert to data frame, then make a tabele and print it
df_results = pd.DataFrame(results)

print(df_results)

#save table to csv
df_results.to_csv('derivatives_results.csv', index=False)  #index=False so dataframe excluded from results. 
print("CSV file saved as 'derivatives_results.csv'")
# Out:
#                                        method function  point      stepsize  \
# 0                         Forward Differrence   cos(x)      5  3.141593e-01
# 1                         Forward Differrence   cos(x)      5  2.356194e-01
# 2                         Forward Differrence   cos(x)      5  1.570796e-01
# 3                         Forward Differrence   cos(x)      5  7.853982e-02
# 4                         Forward Differrence   cos(x)      5  2.220446e-16
# ..                                        ...      ...    ...           ...
# 115  Central Difference for second derivative    $e^x$     20  3.141593e-01
# 116  Central Difference for second derivative    $e^x$     20  2.356194e-01
# 117  Central Difference for second derivative    $e^x$     20  1.570796e-01
# 118  Central Difference for second derivative    $e^x$     20  7.853982e-02
# 119  Central Difference for second derivative    $e^x$     20  2.220446e-16
#
#             num_d        anal_d  rel_error
# 0    8.990360e-01  9.589243e-01   0.062454
# 1    9.168123e-01  9.589243e-01   0.043916
# 2    9.327527e-01  9.589243e-01   0.027293
# 3    9.468051e-01  9.589243e-01   0.012638
# 4    0.000000e+00  9.589243e-01   1.000000
# ..            ...           ...        ...
# 115  4.891687e+08  4.851652e+08   0.008252
# 116  4.874139e+08  4.851652e+08   0.004635
# 117  4.861636e+08  4.851652e+08   0.002058
# 118  4.854146e+08  4.851652e+08   0.000514
# 119  0.000000e+00  4.851652e+08   1.000000
#
# [120 rows x 7 columns]
# CSV file saved as 'derivatives_results.csv'

# %%
readme_file = "README.md"

def generate_markdown_for_plot(image_path):
    return f"![Plot for {os.path.basename(image_path)}]({image_path})\n"

#open up README file in append mode, add plots
with open(readme_file, "a") as f:
    f.write("\n## Generated Plots\n")
    for plot_file in plot_files:
        f.write(generate_markdown_for_plot(plot_file))

print(f"Plots added to {readme_file}")
# Out:
# Plots added to README.md
